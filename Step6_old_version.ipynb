# %% [markdown]
# Step 6: Non-stationary demand curves

# %%
#uncertain graph weights (different click influence probabilities between the products for each user)
#homogeneous users (one class with small variability)
#uncertain alphas
#uncertain number of items sold per product
#uncertain conversion rates

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from Environment.E_commerce import *
from Algorithms.Conv_rates_Learner import *
from Algorithms.TS_Learner_poisson import *
from Algorithms.Learner_Environment import *
from Algorithms.SWTS_Learner import *
from Algorithms.UCB_Learner import *
from Algorithms.Greedy_Learner import *
from Algorithms.Estimate_click_probabilities import *
from Algorithms.SW_UCB_Learner import SW_UCB
from Algorithms.CD_UCB_Learner import *

# %%
#Random algorithm which for each round pulls a random choice 
#to estimate asymptotically the conv_rates and the mean of the number of units sold per product,
#useful for computing clairvoyant solution and regrets of the bandit algorithms

P1 = Product(0,[19.99, 21.99, 23.99, 26.99],np.multiply([0.2, 0.2, 0.2, 0.2],[19.99, 19.99, 19.99, 19.99])+[0, 21.99-19.99, 23.99-19.99, 26.99-19.99])
# t-shirt
P2 = Product(1,[29.99, 32.59, 35.99, 39.99],np.multiply([0.2, 0.2, 0.2, 0.2],[29.99, 29.99, 29.99, 29.99])+[29.99, 32.59, 35.99, 39.99]-29.99)
# shirt
P3 = Product(2,[25.99,28.99, 31.99, 34.99],np.multiply([0.3, 0.3, 0.3, 0.3],[25.99,25.99, 25.99, 25.99])+[25.99,28.99, 31.99, 34.99]-25.99)
# shorts
P4 = Product(3,[38.99,43.99,46.99, 49.99],np.multiply([0.4, 0.4, 0.4, 0.4],[38.99,38.99,38.99, 38.99])+[38.99,43.99,46.99, 49.99]-38.99)
# pants
P5 = Product(4,[79.99,89.99, 99.99, 109.99],np.multiply([0.5, 0.5, 0.5, 0.5],[79.99,79.99, 79.99, 79.99])+[79.99,89.99, 99.99, 109.99]-79.99)
# shoes

products = [P1,P2,P3,P4,P5]
margins_matrix = np.zeros((5,4))
expected_units_sold_per_product = np.array([2,1,3,3,1]) #theese are the lambdas defined in the visit function
for i in range(5):
    for j in range(4):
        margins_matrix[i,j] = products[i].margins_list[j]
E = E_commerce(binary_features=1)
E.set_lambda(0.5)
E.set_products(products)

#Ecommerce graph weights are uncertain, for each user they are different, but the slots are fixed by the Ecommerce
E.graph = np.array([[0. , 0., 1. , 0.5 , 0. ],[0. , 0. , 0.5 , 1., 0. ],[0.5 , 1. , 0. , 0. , 0. ],[1. , 0.5 , 0. , 0. , 0. ],[0. , 0.5 , 0. , 1. , 0. ]])

n_arms = 4
num_users = 100
n_days = 1000
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
num_experiments = 10
opt_vector = np.zeros(num_experiments)
conv_rates_per_experiment = []
mean_units_sold_per_product_per_eperiment = []
cr_learner_expected_rewards_per_experiment = []

for e in range(num_experiments):
    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha, fixed_weights,fixed_units)
    cr_learner = Conv_rates(n_arms=n_arms)

    for d in range(n_days):
        #if (d==30):
        #    User0.setprice()
        pulled_arm = cr_learner.pull_arm()
        reward = env.round(pulled_arm)
        cr_learner.update(pulled_arm, reward, env.clicks_current_day, env.purchases_current_day,env.daily_units)


    conversion_rates = np.zeros((5,4))
    np.set_printoptions(suppress=True)
    for i in range(5):
        conversion_rates[i] = cr_learner.beta_parameters[i][:,0]/(cr_learner.beta_parameters[i][:,0]+cr_learner.beta_parameters[i][:,1])
        opt_vector[e] += np.max(np.array(E.products[i].margins_list) * conversion_rates[i] * cr_learner.lambda_poisson[i])

    conv_rates_per_experiment.append(conversion_rates)
    mean_units_sold_per_product_per_eperiment.append(cr_learner.lambda_poisson)
    cr_learner_expected_rewards_per_experiment.append(cr_learner.expected_rewards)

#optimal expected clarvoyant solution is given chosing each round the best combination
opt1 = np.mean(opt_vector) #+ np.std(opt_vector)
best_arm_per_product = np.zeros(5)
for i in range(5):   
    best_arm_per_product[i] = np.argmax(np.array(E.products[i].margins_list) * np.mean(conv_rates_per_experiment,axis=0)[i] 
                                        * np.mean(mean_units_sold_per_product_per_eperiment, axis = 0)[i])#expected_units_sold_per_product[i])#
    
print("_______________________________________________")
print("Conversion rates")
print(np.mean(conv_rates_per_experiment,axis=0))
print("_______________________________________________")
print("Expected rewards per arm")
print(np.mean(cr_learner_expected_rewards_per_experiment,axis=0))
print("_______________________________________________")
print("Expected units sold per arm")
print(np.mean(mean_units_sold_per_product_per_eperiment, axis = 0))

print("_______________________________________________")
print("Best configuration", best_arm_per_product)
print("Optimal cumulative expected reward per round")
print(opt1) # optimal configuration: the best combination of arms
# Out:
# _______________________________________________
# Conversion rates
# [[0.82351837 0.41365588 0.09919391 0.00151949]
#  [0.84876524 0.46489434 0.06255017 0.00061662]
#  [0.95055845 0.55156246 0.10502806 0.00287891]
#  [0.96000475 0.52258003 0.16930087 0.02192376]
#  [0.99667393 0.70546683 0.29637654 0.02014756]]
# _______________________________________________
# Expected rewards per arm
# [[ 6.58470652  4.95757225  1.58388456  0.030298  ]
#  [ 5.08870952  3.99556695  0.7487165   0.0077399 ]
#  [22.24141419 17.85187586  4.33805669  0.13358828]
#  [44.91771128 32.22159875 11.94627641  1.7398532 ]
#  [39.86770568 35.25860538 17.795091    1.39634056]]
# _______________________________________________
# Expected units sold per arm
# [[2. 2. 2. 2.]
#  [1. 1. 1. 1.]
#  [3. 3. 3. 3.]
#  [3. 3. 3. 3.]
#  [1. 1. 1. 1.]]
# _______________________________________________
# Best configuration [0. 0. 0. 0. 0.]
# Optimal cumulative expected reward per round
# 118.68893532802524

# %%
opt1
# Out:
# 118.68893532802524

# %% [markdown]
# The initial optimal cumulative expected reward per round is 118.54

# %%
#Ecommerce graph weights are uncertain, for each user they are different, but the slots are fixed by the Ecommerce
E.graph = np.array([[0. , 0., 1. , 0.5 , 0. ],[0. , 0. , 0.5 , 1., 0. ],[0.5 , 1. , 0. , 0. , 0. ],[1. , 0.5 , 0. , 0. , 0. ],[0. , 0.5 , 0. , 1. , 0. ]])
n_arms = 4
num_users = 100
n_days = 1000
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
num_experiments = 10
opt_vector = np.zeros(num_experiments)
conv_rates_per_experiment = []
mean_units_sold_per_product_per_eperiment = []
cr_learner_expected_rewards_per_experiment = []
change = [np.array([1.15,0.95,1.2,0.9,1]) for _ in range(3) ]

for e in range(num_experiments):
    #reset_users_reserv_prices() viene chiamato quando crei env
    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha, fixed_weights,fixed_units)
    print("Original reservation prices:")
    print(User0.avg_reservation_price)
    print(User1.avg_reservation_price)
    print(User2.avg_reservation_price)
    env.abrupt_change([0,1,2],change)

    cr_learner = Conv_rates(n_arms=n_arms)

    for d in range(n_days):
        #if (d==30):
        #    User0.setprice()
        pulled_arm = cr_learner.pull_arm()
        reward = env.round(pulled_arm)
        cr_learner.update(pulled_arm, reward, env.clicks_current_day, env.purchases_current_day,env.daily_units)


    conversion_rates = np.zeros((5,4))
    np.set_printoptions(suppress=True)
    for i in range(5):
        conversion_rates[i] = cr_learner.beta_parameters[i][:,0]/(cr_learner.beta_parameters[i][:,0]+cr_learner.beta_parameters[i][:,1])
        opt_vector[e] += np.max(np.array(E.products[i].margins_list) * conversion_rates[i] * cr_learner.lambda_poisson[i])

    conv_rates_per_experiment.append(conversion_rates)
    mean_units_sold_per_product_per_eperiment.append(cr_learner.lambda_poisson)
    cr_learner_expected_rewards_per_experiment.append(cr_learner.expected_rewards)

#optimal expected clarvoyant solution is given chosing each round the best combination
opt2 = np.mean(opt_vector) #+ np.std(opt_vector)
best_arm_per_product = np.zeros(5)
for i in range(5):
    best_arm_per_product[i] = np.argmax(np.array(E.products[i].margins_list) * np.mean(conv_rates_per_experiment,axis=0)[i]
                                        * np.mean(mean_units_sold_per_product_per_eperiment, axis = 0)[i])#expected_units_sold_per_product[i])#

print("_______________________________________________")
print("Conversion rates")
print(np.mean(conv_rates_per_experiment,axis=0))
print("_______________________________________________")
print("Expected rewards per arm")
print(np.mean(cr_learner_expected_rewards_per_experiment,axis=0))
print("_______________________________________________")
print("Expected units sold per arm")
print(np.mean(mean_units_sold_per_product_per_eperiment, axis = 0))

print("_______________________________________________")
print("Best configuration", best_arm_per_product)
print("Optimal cumulative expected reward per round")
print(opt2) # optimal configuration: the best combination of arms
# Out:
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# Original reservation prices:
# [ 23  34  31  46 104]
# [21 32 29 44 95]
# [21 31 28 42 87]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# _______________________________________________
# Conversion rates
# [[0.9977631  0.94822231 0.66985122 0.13158235]
#  [0.62553028 0.21298579 0.01206441 0.00014265]
#  [0.99980761 0.99876488 0.92840237 0.51635138]
#  [0.60236456 0.06643109 0.00490337 0.00019726]
#  [0.99719046 0.70385585 0.29450283 0.02086012]]
# _______________________________________________
# Expected rewards per arm
# [[ 7.97905955 11.37709525 10.70241739  2.8774495 ]
#  [ 3.75331038  1.83032325  0.14298004  0.        ]
#  [23.391      32.35796611 38.42082666 26.0394358 ]
#  [28.13432829  4.10033308  0.3300494   0.00383713]
#  [39.89075342 35.17574942 17.68192105  1.46120054]]
# _______________________________________________
# Expected units sold per arm
# [[2.  2.  2.  2. ]
#  [1.  1.  1.  0. ]
#  [3.  3.  3.  3. ]
#  [3.  3.  3.  1.2]
#  [1.  1.  1.  1. ]]
# _______________________________________________
# Best configuration [1. 0. 2. 0. 0.]
# Optimal cumulative expected reward per round
# 121.62037289835261

# %% [markdown]
# ## SW-TS (skip it)

# %%
n_arms = 4
num_users = 100
n_days = 1000
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
num_experiments = 10
opt_vector = np.zeros(num_experiments)
conv_rates_per_experiment = []
mean_units_sold_per_product_per_eperiment = []
cr_learner_expected_rewards_per_experiment = []

for e in range(num_experiments):
    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha, fixed_weights,fixed_units)
    cr_learner = Conv_rates(n_arms=n_arms)

    for d in range(n_days):
        #if (d==30):
        #    User0.setprice()
        pulled_arm = cr_learner.pull_arm()
        reward = env.round(pulled_arm)
        cr_learner.update(pulled_arm, reward, env.clicks_current_day, env.purchases_current_day,env.daily_units)


    conversion_rates = np.zeros((5,4))
    np.set_printoptions(suppress=True)
    for i in range(5):
        conversion_rates[i] = cr_learner.beta_parameters[i][:,0]/(cr_learner.beta_parameters[i][:,0]+cr_learner.beta_parameters[i][:,1])
        opt_vector[e] += np.max(np.array(E.products[i].margins_list) * conversion_rates[i] * cr_learner.lambda_poisson[i])

    conv_rates_per_experiment.append(conversion_rates)
    mean_units_sold_per_product_per_eperiment.append(cr_learner.lambda_poisson)
    cr_learner_expected_rewards_per_experiment.append(cr_learner.expected_rewards)

#optimal expected clarvoyant solution is given chosing each round the best combination
opt = np.mean(opt_vector) #+ np.std(opt_vector)
best_arm_per_product = np.zeros(5)
for i in range(5):
    best_arm_per_product[i] = np.argmax(np.array(E.products[i].margins_list) * np.mean(conv_rates_per_experiment,axis=0)[i]
                                        * np.mean(mean_units_sold_per_product_per_eperiment, axis = 0)[i])#expected_units_sold_per_product[i])#

print("_______________________________________________")
print("Conversion rates")
print(np.mean(conv_rates_per_experiment,axis=0))
print("_______________________________________________")
print("Expected rewards per arm")
print(np.mean(cr_learner_expected_rewards_per_experiment,axis=0))
print("_______________________________________________")
print("Expected units sold per arm")
print(np.mean(mean_units_sold_per_product_per_eperiment, axis = 0))

print("_______________________________________________")
print("Best configuration", best_arm_per_product)
print("Optimal cumulative expected reward per round")
print(opt) # optimal configuration: the best combination of arms

# %% [markdown]
# It was not asked, but I wrote it. Unfortunately, it is giving some errors sometimes.

# %%
#Comparison between TS and SW-TS
from Algorithms.SWTS_Learner import *
n_arms = 4
num_users = 100
n_days = 1000
fixed_alpha = 1
fixed_weights = 0
fixed_units = 1  # 0 ?
n_experiments = 10

window_size = 100

swts_rewards_per_experiment = []
ts_rewards_per_experiment = []

swts_pulls_per_arm_per_experiment = []
ts_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ts_learner = TS_poisson(n_arms=n_arms)
    swts_learner = SW_TS(n_arms, window_size)

    for d in range(n_days):

        pulled_arm = ts_learner.pull_arm(env.margins_matrix)
        reward = env.round(pulled_arm)
        ts_learner.update(pulled_arm, reward,env.clicks_current_day, env.purchases_current_day,  env.daily_units)

        pulled_arm = swts_learner.pull_arm(env.margins_matrix)
        reward = env.round(pulled_arm)
        swts_learner.update(pulled_arm, reward, env.clicks_current_day, env.purchases_current_day, env.daily_units)

    swts_rewards_per_experiment.append(swts_learner.collected_rewards)
    ts_rewards_per_experiment.append(ts_learner.collected_rewards)


    swts_pulls_per_arm_per_experiment.append(swts_learner.counter_per_arm)
    ts_pulls_per_arm_per_experiment.append(ts_learner.counter_per_arm)

# %%
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")
plt.plot(np.cumsum(np.mean(opt - swts_rewards_per_experiment, axis=0)), 'r')
plt.plot(np.cumsum(np.mean(opt - ts_rewards_per_experiment, axis=0)), 'b')
plt.legend(["Greedy","TS","UCB","random"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f0b553b72e52> in <module>
#       2 plt.xlabel("t")
#       3 plt.ylabel("Regret")
# ----> 4 plt.plot(np.cumsum(np.mean(opt - swts_rewards_per_experiment, axis=0)), 'r')
#       5 plt.plot(np.cumsum(np.mean(opt - ts_rewards_per_experiment, axis=0)), 'b')
#       6 plt.legend(["Greedy","TS","UCB","random"])
#
# NameError: name 'swts_rewards_per_experiment' is not defined

# %% [markdown]
# ## SW-UCB

# %% [markdown]
# ### Simulation in a static environment

# %%
#Comparison between SW-UCB and UCB

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
n_experiments = 10

window_size = 90

sw_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

sw_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    sw_UCB_learner = SW_UCB(n_arms, window_size)

    for d in range(n_days):

        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = sw_UCB_learner.pull_arm()
        reward = env.round(pulled_arm, )
        sw_UCB_learner.update(pulled_arm, reward)

    sw_ucb_rewards_per_experiment.append(sw_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)


    sw_ucb_pulls_per_arm_per_experiment.append(sw_UCB_learner.counter_per_arm)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)
# Out:
# /Users/lucamainini/opt/anaconda3/envs/math_environment/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/lucamainini/opt/anaconda3/envs/math_environment/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sw_ucb_rewards_per_experiment

# %%
opt =opt1
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")
plt.plot(np.cumsum(np.mean(opt - sw_ucb_rewards_per_experiment, axis=0)), 'r')
plt.plot(np.cumsum(np.mean(opt - ucb_rewards_per_experiment, axis=0)), 'b')
plt.legend(["SW UCB","UCB"])
plt.show()

# %% [markdown]
# Come previsto, SW UCB si comporta peggio di UCB (in un AMBIENTE STATICO).

# %%
#Comparison between SW-UCB and UCB in a dynamic environment

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 0
fixed_units = 1  # 0 ?
n_experiments = 10

days_of_change = [100]

window_size = 90

sw_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

sw_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    sw_UCB_learner = SW_UCB(n_arms, window_size)

    for d in range(n_days):
        for day_of_change in days_of_change:
            if d==day_of_change:
                env.abrupt_change([0,1,2],change)
        print(User0.avg_reservation_price)

        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = sw_UCB_learner.pull_arm()
        reward = env.round(pulled_arm, )
        sw_UCB_learner.update(pulled_arm, reward)

    sw_ucb_rewards_per_experiment.append(sw_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)


    sw_ucb_pulls_per_arm_per_experiment.append(sw_UCB_learner.counter_per_arm)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)
# Out:
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# ...
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# [ 23  34  31  46 104]
# Abrupt change
# class User 0 has changed: its new average reservation price is [ 26.45  32.3   37.2   41.4  104.  ]
# class User 1 has changed: its new average reservation price is [24.15 30.4  34.8  39.6  95.  ]
# class User 2 has changed: its new average reservation price is [24.15 29.45 33.6  37.8  87.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]
# [ 26.45  32.3   37.2   41.4  104.  ]

# %%
days_of_change[0]
# Out:
# 100

# %%
sw_ucb_rewards = np.mean(sw_ucb_rewards_per_experiment, axis=0)
ucb_rewards = np.mean(ucb_rewards_per_experiment, axis=0)

# %%
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")
plot1 = np.concatenate((np.cumsum(opt1-sw_ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-sw_ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-sw_ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot1, 'r')
plot2 = np.concatenate((np.cumsum(opt1-ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot2, 'b')

plt.legend(["SW UCB","UCB"])
plt.show()

# %% [markdown]
# Questa volta SW-UCB si comporta meglio!

# %%
opt1, opt2
# Out:
# (118.68893532802524, 121.62037289835261)

# %% [markdown]
# ## SD1-UCB [skip it]

# %%
#Comparison between SD1-UCB and UCB
# static environment

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1  # 0 ?
n_experiments = 10

window_size = 100

cd_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

cd_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    cd_UCB_learner = CD1_UCB(n_arms, window_size)

    for d in range(n_days):

        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = cd_UCB_learner.pull_arm()
        reward = env.round(pulled_arm, )
        cd_UCB_learner.update(pulled_arm, reward)

    cd_ucb_rewards_per_experiment.append(cd_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)


    cd_ucb_pulls_per_arm_per_experiment.append(cd_UCB_learner.counter_per_arm)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)

# %%
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")
sw_ucb_rewards = np.mean(sw_ucb_rewards_per_experiment, axis=0)
ucb_rewards = np.mean(ucb_rewards_per_experiment, axis=0)

plt.plot(np.cumsum(np.mean(opt1 - cd_ucb_rewards_per_experiment, axis=0)), 'r')
plt.plot(np.cumsum(np.mean(opt1 - ucb_rewards_per_experiment, axis=0)), 'b')
plt.legend(["CD1-UCB","UCB"])
plt.show()

# %%
#Comparison between SD1-UCB and UCB
# dynamic environment

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
n_experiments = 10

window_size = 90

days_of_change = [100]


cd_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

cd_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    cd_UCB_learner = CD1_UCB(n_arms, window_size)

    for d in range(n_days):
        for day_of_change in days_of_change:
            if d==day_of_change:
                env.abrupt_change([0,1,2],change)

        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = cd_UCB_learner.pull_arm()
        reward = env.round(pulled_arm, )
        cd_UCB_learner.update(pulled_arm, reward)

    cd_ucb_rewards_per_experiment.append(cd_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)


    cd_ucb_pulls_per_arm_per_experiment.append(cd_UCB_learner.counter_per_arm)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)

plt.figure(0)
plt.xlabel("t")
plt.ylabel("Rewards:")
plt.plot(np.cumsum(np.mean(cd_ucb_rewards_per_experiment, axis=0)), 'r')
plt.plot(np.cumsum(np.mean(ucb_rewards_per_experiment, axis=0)), 'b')
plt.legend(["CD1-UCB","UCB"])
plt.show()

# %%
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")

cd_ucb_rewards = np.mean(cd_ucb_rewards_per_experiment, axis=0)
ucb_rewards = np.mean(ucb_rewards_per_experiment, axis=0)

plot1 = np.concatenate((np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-cd_ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot1, 'r')
plot2 = np.concatenate((np.cumsum(opt1-ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot2, 'b')

plt.legend(["CD1-UCB","UCB"])
plt.show()

# %% [markdown]
# --> LOOK AT THIS ONE: usando il secondo algoritmo (CUSUM 2), quello del paper

# %%
#Comparison between CU-SUM UCB and UCB
# static environment

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 1
fixed_units = 1
n_experiments = 10

window_size = 90

cd_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

cd_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []

for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha, fixed_weights, fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    cd_UCB_learner = CUSUM_UCB(n_arms)

    for d in range(n_days):
        print('day ', d)
        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = cd_UCB_learner.pull_arm()
        print(pulled_arm)
        reward = env.round(pulled_arm, )
        cd_UCB_learner.update(pulled_arm, reward, env.purchases_current_day,env.clicks_current_day)

    cd_ucb_rewards_per_experiment.append(cd_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)

    cd_ucb_pulls_per_arm_per_experiment.append(cd_UCB_learner.counter_per_arm,)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)

plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regret")
plt.plot(np.cumsum(np.mean(opt - cd_ucb_rewards_per_experiment, axis=0)), 'r')
plt.plot(np.cumsum(np.mean(opt - ucb_rewards_per_experiment, axis=0)), 'b')
plt.legend(["CUSUM-UCB", "UCB"])
plt.show()
# Out:
# day  0
# [0 0 0 0 0]
# pulled arm: [0 0 0 0 0]
# running CUSUM algorithm on product 0 arm 0
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# troppo presto
# day  1
# [1 1 1 1 1]
# pulled arm: [1 1 1 1 1]
# running CUSUM algorithm on product 0 arm 1
# troppo presto
# running CUSUM algorithm on product 1 arm 1
# troppo presto
# running CUSUM algorithm on product 2 arm 1
# troppo presto
# running CUSUM algorithm on product 3 arm 1
# troppo presto
# running CUSUM algorithm on product 4 arm 1
# troppo presto
# day  2
# [2 2 2 2 2]
# pulled arm: [2 2 2 2 2]
# running CUSUM algorithm on product 0 arm 2
# troppo presto
# running CUSUM algorithm on product 1 arm 2
# troppo presto
# running CUSUM algorithm on product 2 arm 2
# troppo presto
# running CUSUM algorithm on product 3 arm 2
# troppo presto
# running CUSUM algorithm on product 4 arm 2
# troppo presto
# day  3
# [3 3 3 3 3]
# pulled arm: [3 3 3 3 3]
# running CUSUM algorithm on product 0 arm 3
# troppo presto
# running CUSUM algorithm on product 1 arm 3
# troppo presto
# running CUSUM algorithm on product 2 arm 3
# troppo presto
# running CUSUM algorithm on product 3 arm 3
# troppo presto
# running CUSUM algorithm on product 4 arm 3
# troppo presto
# day  4
# [0 0 0 0 0]
# pulled arm: [0 0 0 0 0]
# running CUSUM algorithm on product 0 arm 0
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# troppo presto
# day  5
# [1 1 1 1 1]
# pulled arm: [1 1 1 1 1]
# running CUSUM algorithm on product 0 arm 1
# troppo presto
# running CUSUM algorithm on product 1 arm 1
# troppo presto
# running CUSUM algorithm on product 2 arm 1
# troppo presto
# running CUSUM algorithm on product 3 arm 1
# troppo presto
# running CUSUM algorithm on product 4 arm 1
# troppo presto
# day  6
# [2 2 2 2 2]
# pulled arm: [2 2 2 2 2]
# running CUSUM algorithm on product 0 arm 2
# troppo presto
# running CUSUM algorithm on product 1 arm 2
# troppo presto
# running CUSUM algorithm on product 2 arm 2
# troppo presto
# running CUSUM algorithm on product 3 arm 2
# troppo presto
# running CUSUM algorithm on product 4 arm 2
# troppo presto
# day  7
# [3 3 3 3 3]
# pulled arm: [3 3 3 3 3]
# running CUSUM algorithm on product 0 arm 3
# troppo presto
# running CUSUM algorithm on product 1 arm 3
# troppo presto
# running CUSUM algorithm on product 2 arm 3
# troppo presto
# running CUSUM algorithm on product 3 arm 3
# troppo presto
# running CUSUM algorithm on product 4 arm 3
# troppo presto
# day  8
# [1. 0. 0. 0. 0.]
# pulled arm: [1. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 1
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# troppo presto
# day  9
# [0. 0. 1. 0. 1.]
# pulled arm: [0. 0. 1. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# troppo presto
# running CUSUM algorithm on product 2 arm 1
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# troppo presto
# running CUSUM algorithm on product 4 arm 1
# troppo presto
# day  10
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# troppo presto
# running CUSUM algorithm on product 1 arm 1
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# the mean over M steps is: 0.9656982775587426
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# troppo presto
# day  11
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# the mean over M steps is: 0.7763631342223626
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# the mean over M steps is: 0.8571143871143871
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# the mean over M steps is: 0.9468288233505625
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# the mean over M steps is: 1.0
# troppo presto
# day  12
# [1. 0. 0. 0. 1.]
# pulled arm: [1. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 1
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.814029484029485
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 1
# troppo presto
# day  13
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 1
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  14
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 1
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  15
# [0. 0. 0. 1. 0.]
# pulled arm: [0. 0. 0. 1. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 1
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  16
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 7.439994476445987
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 3.4627931102349705
# running CUSUM algorithm on product 4 arm 1
# the mean over M steps is: 0.7161904761904762
# troppo presto
# day  17
# [1. 0. 1. 0. 0.]
# pulled arm: [1. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 1
# the mean over M steps is: 0.4419893739766062
# troppo presto
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 1
# the mean over M steps is: 0.5794679005205321
# troppo presto
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  18
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  19
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.08001657066203505
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  20
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 5.4109050737789
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 4.313333333333333
# day  21
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.47273731555274834
# g_decrease 1.3527262684447252
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  22
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.305480154659509
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  23
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.520038664878082
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 0
# g_decrease 4.794679005205321
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  24
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  25
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 1
# the mean over M steps is: 0.5069057447540419
# troppo presto
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 2.540486470051688
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  26
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.9563797048843976
# g_decrease 1.3527262684447252
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 8.545020639834878
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  27
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 6.087268208001262
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  28
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.3381953759962104
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  29
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.6971428571428566
# day  30
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 2.540486470051688
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  31
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 7.439994476445987
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 9.35883212934296
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  32
# [1. 0. 0. 0. 1.]
# pulled arm: [1. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 1
# mean_over_M:  0.4419893739766062
# g_increase 0
# g_decrease 7.523766227485334
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.6971428571428566
# day  33
# [1. 0. 0. 0. 0.]
# pulled arm: [1. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 1
# mean_over_M:  0.4419893739766062
# g_increase 0
# g_decrease 6.839787479532122
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  34
# [0. 0. 0. 1. 0.]
# pulled arm: [0. 0. 0. 1. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 5.31998342933796
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 2.540486470051688
# running CUSUM algorithm on product 3 arm 1
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  35
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 3.381815671111813
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 2.540486470051688
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  36
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 7.439994476445987
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.814029484029485
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  37
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 8.138114895080836
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  38
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.7091059733291227
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 5.284575484575488
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.0809523809523807
# day  39
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  40
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 9.765737874097002
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  41
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 5.29980070980071
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  42
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0.1247619047619053
# g_decrease 1.8485714285714285
# day  43
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.7200110471080232
# g_decrease 1.3527262684447252
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.0809523809523807
# day  44
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.4182119466582455
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  45
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.003681054209731194
# g_decrease 3.381815671111813
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  46
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.0284575484575487
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 0
# g_decrease 5.863504916136495
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 3.4627931102349705
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  47
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  48
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.5854691075514853
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 7.571143871143872
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  49
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 3.381815671111813
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.5559186459186503
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  50
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 6.087268208001262
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 7.571143871143872
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  51
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 9.584376194376198
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  52
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.8689516789516825
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.0809523809523807
# day  53
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  54
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 5.4109050737789
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 5.5457142857142845
# day  55
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 7.439994476445987
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 4.328491387793713
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  56
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 5.29980070980071
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  57
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 4.328491387793713
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  58
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  59
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  60
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 6.087268208001262
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  61
# [1. 0. 0. 1. 0.]
# pulled arm: [1. 0. 0. 1. 0.]
# running CUSUM algorithm on product 0 arm 1
# mean_over_M:  0.4419893739766062
# g_increase 0
# g_decrease 7.181776853508728
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 5.29980070980071
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 1
# the mean over M steps is: 0.5139250943292295
# troppo presto
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  62
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 6.087268208001262
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  63
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 5.4109050737789
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  64
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  65
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 7.439994476445987
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  66
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.672709697782686
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 5.29980070980071
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  67
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.46183224177384785
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 7.566004471964215
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  68
# [0. 1. 0. 0. 0.]
# pulled arm: [0. 1. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 1
# mean_over_M:  0.5069057447540419
# g_increase 0
# g_decrease 9.765737874097002
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  69
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.734541939556538
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  70
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 4.058178805334175
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  71
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 1.5142287742287743
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 2.4647619047619047
# day  72
# [0. 0. 1. 0. 1.]
# pulled arm: [0. 0. 1. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.20365343643967249
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 6.056915096915097
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 0
# g_decrease 4.794679005205321
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 4.313333333333333
# day  73
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 1.693657646701125
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  74
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.7091059733291227
# g_decrease 1.3527262684447252
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 1.0517061885482941
# g_decrease 2.8768074031231925
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  75
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.6654856782135203
# g_decrease 3.381815671111813
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 0
# g_decrease 3.8357432041642565
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  76
# [0. 0. 1. 0. 0.]
# pulled arm: [0. 0. 1. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.7455022488755558
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 1
# mean_over_M:  0.5794679005205321
# g_increase 0
# g_decrease 3.3562753036437245
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  77
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.8364238933164918
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 3.785571935571936
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  78
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 1.0400773297561647
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 4.542686322686323
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  79
# [0. 0. 0. 0. 1.]
# pulled arm: [0. 0. 0. 0. 1.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.9964570346405628
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 2.2713431613431614
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 1
# mean_over_M:  0.7161904761904762
# g_increase 0
# g_decrease 3.1723809523809496
# day  80
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.8291998737473234
# g_decrease 2.7054525368894504
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 8.32825825825826
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 0.8656982775587426
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  81
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 5.4109050737789
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 13.398405678405679
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 1.7313965551174852
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  82
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0
# g_decrease 3.381815671111813
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# g_decrease 9.411638001637987
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9468288233505625
# g_increase 0
# g_decrease 0.8468288233505625
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9656982775587426
# g_increase 0
# g_decrease 2.5970948326762278
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  83
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.7763631342223626
# g_increase 0.9563797048843976
# g_decrease 2.029089402667088
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8571143871143871
# g_increase 0
# ...
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  340
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 5.533635609230715
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.9495989537925027
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  341
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.810346240090401
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 5.16179816913688
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 2.5615844155844156
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 1.695529887800911
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  342
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 7.509892826244328
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.9495989537925027
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 2.543294831701367
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  343
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.003957130497731
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 7.373997384481257
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  344
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 5.256924978371029
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 7.182988230165655
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 1.7077229437229438
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 1.695529887800911
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  345
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 2.252967847873298
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 1.7077229437229438
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 1.695529887800911
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  346
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.003957130497731
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 1.7077229437229438
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  347
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 5.256924978371029
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  348
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.0316570439818493
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.9495989537925027
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 2.5615844155844156
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  349
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 1.5019785652488655
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 1.629210985178721
# g_decrease 0.7373997384481257
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  350
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.754946413122164
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 5.16179816913688
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  351
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 4.505935695746596
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 6.636597646033131
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  352
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 2.252967847873298
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 4.596791630340022
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  353
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 6.007914260995462
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.9495989537925027
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 2.5615844155844156
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  354
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 6.758903543619895
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.212199215344377
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 2.5615844155844156
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  355
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 11.790560587601746
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 5.16179816913688
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 3.4154458874458875
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 2.543294831701367
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  356
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 10.071228348959165
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 4.424398430688754
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.49267532467532504
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 3.391059775601822
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  357
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 8.347938979818853
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0.6902070619006078
# g_decrease 0.7373997384481257
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  358
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 7.628606741176272
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0.6934154315605854
# g_decrease 1.4747994768962513
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 1.7077229437229438
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 2.543294831701367
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  359
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 5.9053173720359595
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 1.695529887800911
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  360
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.9330172855200782
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 2.212199215344377
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0.9
# day  361
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 4.505935695746596
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 4.424398430688754
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 2.5615844155844156
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 1.695529887800911
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  362
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 3.754946413122164
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  363
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 6.007914260995462
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 3.6869986922406284
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 0.8477649439004555
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# day  364
# [0. 0. 0. 0. 0.]
# pulled arm: [0. 0. 0. 0. 0.]
# running CUSUM algorithm on product 0 arm 0
# mean_over_M:  0.8509892826244327
# g_increase 0
# g_decrease 5.256924978371029
# running CUSUM algorithm on product 1 arm 0
# mean_over_M:  0.8373997384481257
# g_increase 0
# g_decrease 5.16179816913688
# running CUSUM algorithm on product 2 arm 0
# mean_over_M:  0.9538614718614719
# g_increase 0
# g_decrease 0.8538614718614719
# running CUSUM algorithm on product 3 arm 0
# mean_over_M:  0.9477649439004555
# g_increase 0
# g_decrease 2.543294831701367
# running CUSUM algorithm on product 4 arm 0
# mean_over_M:  1.0
# g_increase 0
# g_decrease 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 46>()
#      44 plt.xlabel("t")
#      45 plt.ylabel("Regret")
# ---> 46 plt.plot(np.cumsum(np.mean(opt - cd_ucb_rewards_per_experiment, axis=0)), 'r')
#      47 plt.plot(np.cumsum(np.mean(opt - ucb_rewards_per_experiment, axis=0)), 'b')
#      48 plt.legend(["CUSUM-UCB", "UCB"])
#
# NameError: name 'opt' is not defined

# %%
change

# %%
#Comparison between CUSUM-UCB and UCB
# dynamic environment

n_arms = 4
num_users = 100
n_days = 365
fixed_alpha = 1
fixed_weights = 1
fixed_units = 10
n_experiments = 10

M = 20

days_of_change = [100]


cd_ucb_rewards_per_experiment = []
ucb_rewards_per_experiment = []

cd_ucb_pulls_per_arm_per_experiment = []
ucb_pulls_per_arm_per_experiment = []


for e in range(n_experiments):

    env = Environment(n_arms, E, margins_matrix, num_users, fixed_alpha,fixed_weights,fixed_units)
    ucb_learner = UCB(n_arms=n_arms)
    cd_UCB_learner = CUSUM_UCB(n_arms, M,eps=0.1, h=20)

    for d in range(n_days):
        print('--------day--------', d)
        for day_of_change in days_of_change:
            if d==day_of_change:
                env.abrupt_change([0,1,2],change)

        pulled_arm = ucb_learner.pull_arm()
        reward = env.round(pulled_arm)
        ucb_learner.update(pulled_arm, reward)

        pulled_arm = cd_UCB_learner.pull_arm()
        reward = env.round(pulled_arm)
        cd_UCB_learner.update(pulled_arm, reward, env.purchases_current_day,env.clicks_current_day)

    cd_ucb_rewards_per_experiment.append(cd_UCB_learner.collected_rewards)
    ucb_rewards_per_experiment.append(ucb_learner.collected_rewards)


    cd_ucb_pulls_per_arm_per_experiment.append(cd_UCB_learner.counter_per_arm)
    ucb_pulls_per_arm_per_experiment.append(ucb_learner.counter_per_arm)

# %%
for p in range(5):
    for arm in range(4):
        print('product',p, 'arm',arm)
        print(cd_UCB_learner.detections[p][arm])

# %%
plt.figure(0)
plt.xlabel("t")
plt.ylabel("Regrets")

cd_ucb_rewards = np.mean(cd_ucb_rewards_per_experiment, axis=0)
ucb_rewards = np.mean(ucb_rewards_per_experiment, axis=0)

plot1 = np.concatenate((np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-cd_ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot1, 'r')
plot2 = np.concatenate((np.cumsum(opt1-ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot2, 'b')

plt.legend(["CUSUM-UCB","UCB"])
plt.show()

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[0][arm])
plt.legend([0,1,2,3])
plt.title("product 0 - down")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.up[0][arm])
plt.legend([0,1,2,3])
plt.title("product 0 - up")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[1][arm])
plt.legend([0,1,2,3])
plt.title("product 1 - down")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[1][arm])
plt.legend([0,1,2,3])
plt.title("product 1 - up")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[2][arm])
plt.legend([0,1,2,3])
plt.title("product 2 - down")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.up[2][arm])
plt.legend([0,1,2,3])
plt.title("product 2 - up")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[3][arm])
plt.legend([0,1,2,3])
plt.title("product 3 - down")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[3][arm])
plt.legend([0,1,2,3])
plt.title("product 3 - up")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.down[4][arm])
plt.legend([0,1,2,3])
plt.title("product 4 - down")

# %%
plt.figure(0)
plt.xlabel("t")
for arm in range(4):
    plt.plot(cd_UCB_learner.up[4][arm])
plt.legend([0,1,2,3])
plt.title("product 4 - up")

# %%
plt.figure(0)
plt.xlabel("t")

cd_ucb_rewards = np.mean(cd_ucb_rewards_per_experiment, axis=0)
ucb_rewards = np.mean(ucb_rewards_per_experiment, axis=0)

plot1 = np.concatenate((np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-cd_ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-cd_ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot1, 'r')
plot2 = np.concatenate((np.cumsum(opt1-ucb_rewards[1:days_of_change[0]]),
                                  (np.cumsum(opt1-ucb_rewards[1:days_of_change[0]+1])[days_of_change[0]-1]+np.cumsum(opt2-ucb_rewards[days_of_change[0]+1:])
                                            )))
plt.plot(plot2, 'b')

plt.legend(["CUSUM-UCB","UCB"])
plt.show()
